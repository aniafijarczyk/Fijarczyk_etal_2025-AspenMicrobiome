# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # ASV table

# %%
df = pd.read_csv("../../2022_MicrobiomeAspenGreenhouse/01_data_prep/dataPrep_01_overview_ITS_ASV.tsv", sep="\t", header=0)
df.head()
# Out:
#                                   ITS.Ctrl.neg.extraction.Racine  \
# 0432b9b1f641c119c2cfcb80d296ad60                               0
# d245d0e6106daddd281a14becc2342ab                               0
# 024cca61ca860ae60a3c4f992e383f53                               0
# 5e68312f60a629b050527be14bf4c4ab                               0
# a06d6759b29ad98a8324cc7c82876632                               0
#
#                                   ITS.Ctrl.neg.extraction.sol  ITS.Racine.AB1  \
# 0432b9b1f641c119c2cfcb80d296ad60                            0               0
# d245d0e6106daddd281a14becc2342ab                            0             184
# 024cca61ca860ae60a3c4f992e383f53                            0               0
# 5e68312f60a629b050527be14bf4c4ab                            0               0
# a06d6759b29ad98a8324cc7c82876632                            0               2
#
#                                   ITS.Racine.AB11  ITS.Racine.AB12  \
# 0432b9b1f641c119c2cfcb80d296ad60                0                0
# d245d0e6106daddd281a14becc2342ab                0               23
# 024cca61ca860ae60a3c4f992e383f53                0                0
# 5e68312f60a629b050527be14bf4c4ab                0              140
# a06d6759b29ad98a8324cc7c82876632                9                0
#
#                                   ITS.Racine.FORE.001  ITS.Racine.FORE.004  \
# 0432b9b1f641c119c2cfcb80d296ad60                    0                    0
# d245d0e6106daddd281a14becc2342ab                    0                    0
# 024cca61ca860ae60a3c4f992e383f53                    0                    0
# 5e68312f60a629b050527be14bf4c4ab                    0                    8
# a06d6759b29ad98a8324cc7c82876632                    0                    0
#
#                                   ITS.Racine.FORE.007  ITS.Racine.FP2.3.5  \
# 0432b9b1f641c119c2cfcb80d296ad60                    0                   0
# d245d0e6106daddd281a14becc2342ab                    0                   0
# 024cca61ca860ae60a3c4f992e383f53                    0                   0
# 5e68312f60a629b050527be14bf4c4ab                  767                  21
# a06d6759b29ad98a8324cc7c82876632                  101                   0
#
#                                   ITS.Racine.FP2.5.11  ...  ITS.sol.AB12  \
# 0432b9b1f641c119c2cfcb80d296ad60                    0  ...             0
# d245d0e6106daddd281a14becc2342ab                    0  ...             0
# 024cca61ca860ae60a3c4f992e383f53                    0  ...             0
# 5e68312f60a629b050527be14bf4c4ab                 8784  ...           155
# a06d6759b29ad98a8324cc7c82876632                    0  ...            39
#
#                                   ITS.sol.FORE.001  ITS.sol.FORE.004  \
# 0432b9b1f641c119c2cfcb80d296ad60                 0                 0
# d245d0e6106daddd281a14becc2342ab                 0                 0
# 024cca61ca860ae60a3c4f992e383f53                 0                 0
# 5e68312f60a629b050527be14bf4c4ab               154                54
# a06d6759b29ad98a8324cc7c82876632               132                 0
#
#                                   ITS.sol.FORE.007  ITS.sol.FP2.3.5  \
# 0432b9b1f641c119c2cfcb80d296ad60                 0                0
# d245d0e6106daddd281a14becc2342ab                 5                0
# 024cca61ca860ae60a3c4f992e383f53                 0                0
# 5e68312f60a629b050527be14bf4c4ab                55               14
# a06d6759b29ad98a8324cc7c82876632               161                5
#
#                                   ITS.sol.FP2.5.11  ITS.sol.FP2.5.17  \
# 0432b9b1f641c119c2cfcb80d296ad60                 0                 0
# d245d0e6106daddd281a14becc2342ab                19                 0
# 024cca61ca860ae60a3c4f992e383f53                 8                 0
# 5e68312f60a629b050527be14bf4c4ab                45                91
# a06d6759b29ad98a8324cc7c82876632              1085               228
#
#                                   ITS.sol.SP.4  ITS.sol.SP.45  ITS.sol.SP.56
# 0432b9b1f641c119c2cfcb80d296ad60             2              0              0
# d245d0e6106daddd281a14becc2342ab            25             69              0
# 024cca61ca860ae60a3c4f992e383f53             0              0              0
# 5e68312f60a629b050527be14bf4c4ab             0            225             33
# a06d6759b29ad98a8324cc7c82876632          3401            475             18
#
# [5 rows x 38 columns]

# %%
dtax = pd.read_csv("../../2022_MicrobiomeAspenGreenhouse/01_data_prep/dataPrep_01_overview_ITS_TAX.tsv", sep="\t", header=0)
dtax = dtax.fillna("unid")
dtax[dtax['Genus'].str.contains('unident')]
dtax[dtax['Genus'].str.contains('uncult')]
# Out:
# Empty DataFrame
# Columns: [Domain, Phylum, Class, Order, Family, Genus, Species]
# Index: []

# %%
dtax = pd.read_csv("../../2022_MicrobiomeAspenGreenhouse/01_data_prep/dataPrep_01_overview_ITS_TAX.tsv", sep="\t", header=0)
print(dtax.shape)
dtax = dtax.fillna("unid")
#dtax = dtax.drop(columns=['Species'])
dtax['Domain'] = 'Fungi'
dtax['Phylum'] = dtax['Phylum'].str.replace('p__','')
dtax['Class'] = dtax['Class'].str.replace('c__','')
dtax['Order'] = dtax['Order'].str.replace('o__','')
dtax['Family'] = dtax['Family'].str.replace('f__','')
dtax['Genus'] = dtax['Genus'].str.replace('g__','')
dtax['Species'] = dtax['Species'].str.replace('s__','')
dtax = dtax.replace("unidentified","unid")
dtax = dtax.reset_index().rename(columns={'index':'ASV'})
dtax['genus_taxon'] = dtax.apply(lambda x: x['Domain']+'_'+x['Phylum']+'_'+x['Class']+'_'+x['Order']+'_'+x['Family']+'_'+x['Genus'], axis=1)
dtax.head()
# Out:
# (1130, 7)
#                                 ASV Domain                    Phylum  \
# 0  0432b9b1f641c119c2cfcb80d296ad60  Fungi             Basidiomycota
# 1  d245d0e6106daddd281a14becc2342ab  Fungi  Fungi_phy_Incertae_sedis
# 2  024cca61ca860ae60a3c4f992e383f53  Fungi                Ascomycota
# 3  5e68312f60a629b050527be14bf4c4ab  Fungi                Ascomycota
# 4  a06d6759b29ad98a8324cc7c82876632  Fungi                Ascomycota
#
#                       Class                     Order  \
# 0           Wallemiomycetes               Wallemiales
# 1  Fungi_cls_Incertae_sedis  Fungi_ord_Incertae_sedis
# 2             Leotiomycetes                Helotiales
# 3           Dothideomycetes              Pleosporales
# 4           Sordariomycetes               Sordariales
#
#                      Family                     Genus   Species  \
# 0              Wallemiaceae                  Wallemia      unid
# 1  Fungi_fam_Incertae_sedis  Fungi_gen_Incertae_sedis  Fungi_sp
# 2              Mollisiaceae             Phialocephala      unid
# 3             Pleosporaceae                Alternaria      unid
# 4             Chaetomiaceae                      unid      unid
#
#                                          genus_taxon
# 0  Fungi_Basidiomycota_Wallemiomycetes_Wallemiale...
# 1  Fungi_Fungi_phy_Incertae_sedis_Fungi_cls_Incer...
# 2  Fungi_Ascomycota_Leotiomycetes_Helotiales_Moll...
# 3  Fungi_Ascomycota_Dothideomycetes_Pleosporales_...
# 4  Fungi_Ascomycota_Sordariomycetes_Sordariales_C...

# %% [markdown]
# # Groupby up to genus, add consecutive number & ungroup

# %%
unique_genera = dtax.groupby(['Domain','Phylum','Class','Order','Family','Genus','genus_taxon']).agg(n = ('ASV','count')).reset_index()
print(unique_genera.shape)
unique_genera.head()
# Out:
# (226, 8)
#   Domain           Phylum                          Class  \
# 0  Fungi  Aphelidiomycota               Aphelidiomycetes
# 1  Fungi  Aphelidiomycota               Aphelidiomycetes
# 2  Fungi       Ascomycota  Ascomycota_cls_Incertae_sedis
# 3  Fungi       Ascomycota                Dothideomycetes
# 4  Fungi       Ascomycota                Dothideomycetes
#
#                                  Order                               Family  \
# 0  Aphelidiomycetes_ord_Incertae_sedis  Aphelidiomycetes_fam_Incertae_sedis
# 1                                 GS16              GS16_fam_Incertae_sedis
# 2        Ascomycota_ord_Incertae_sedis        Ascomycota_fam_Incertae_sedis
# 3                          Capnodiales                      Cladosporiaceae
# 4                          Capnodiales                      Cladosporiaceae
#
#                                  Genus  \
# 0  Aphelidiomycetes_gen_Incertae_sedis
# 1              GS16_gen_Incertae_sedis
# 2        Ascomycota_gen_Incertae_sedis
# 3                         Cladosporium
# 4                   Toxicocladosporium
#
#                                          genus_taxon  n
# 0  Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelid...  3
# 1  Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS...  5
# 2  Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis...  6
# 3  Fungi_Ascomycota_Dothideomycetes_Capnodiales_C...  4
# 4  Fungi_Ascomycota_Dothideomycetes_Capnodiales_C...  1

# %% [markdown]
# # Adding consecutive numbers to the unique genera

# %%
i=1
new_genus = []
for ind, row in unique_genera.iterrows():
    genus = row['Genus']
    if genus == 'unid':
        new_gen = 'unid'+'_'+str(i)
    else:
        new_gen = genus
    new_genus.append(new_gen)
    i+=1
new_genus
unique_genera['Genus_'] = new_genus
unique_genera.head()
# Out:
#   Domain           Phylum                          Class  \
# 0  Fungi  Aphelidiomycota               Aphelidiomycetes
# 1  Fungi  Aphelidiomycota               Aphelidiomycetes
# 2  Fungi       Ascomycota  Ascomycota_cls_Incertae_sedis
# 3  Fungi       Ascomycota                Dothideomycetes
# 4  Fungi       Ascomycota                Dothideomycetes
#
#                                  Order                               Family  \
# 0  Aphelidiomycetes_ord_Incertae_sedis  Aphelidiomycetes_fam_Incertae_sedis
# 1                                 GS16              GS16_fam_Incertae_sedis
# 2        Ascomycota_ord_Incertae_sedis        Ascomycota_fam_Incertae_sedis
# 3                          Capnodiales                      Cladosporiaceae
# 4                          Capnodiales                      Cladosporiaceae
#
#                                  Genus  \
# 0  Aphelidiomycetes_gen_Incertae_sedis
# 1              GS16_gen_Incertae_sedis
# 2        Ascomycota_gen_Incertae_sedis
# 3                         Cladosporium
# 4                   Toxicocladosporium
#
#                                          genus_taxon  n  \
# 0  Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelid...  3
# 1  Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS...  5
# 2  Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis...  6
# 3  Fungi_Ascomycota_Dothideomycetes_Capnodiales_C...  4
# 4  Fungi_Ascomycota_Dothideomycetes_Capnodiales_C...  1
#
#                                 Genus_
# 0  Aphelidiomycetes_gen_Incertae_sedis
# 1              GS16_gen_Incertae_sedis
# 2        Ascomycota_gen_Incertae_sedis
# 3                         Cladosporium
# 4                   Toxicocladosporium

# %% [markdown]
# # Naming unidentified

# %%
full_genus = []
for ind, row in unique_genera.iterrows():
    genus = row['Genus']
    if genus == 'unid':
        previous = [row['Domain'],row['Phylum'], row['Class'], row['Order'], row['Family']]
        previous_nonan = [ele for ele in previous if ele != 'unid']
        if previous_nonan:
            descriptor = previous_nonan[-1]
            full_gen = row['Genus_'] + "_" + descriptor
            #full_gen = row['Genus_']
        else:
            full_gen = row['Genus_']
    else:
        full_gen = row['Genus_']
    full_genus.append(full_gen)
unique_genera['taxon'] = full_genus
unique_genera.head()
# Out:
#   Domain           Phylum                          Class  \
# 0  Fungi  Aphelidiomycota               Aphelidiomycetes
# 1  Fungi  Aphelidiomycota               Aphelidiomycetes
# 2  Fungi       Ascomycota  Ascomycota_cls_Incertae_sedis
# 3  Fungi       Ascomycota                Dothideomycetes
# 4  Fungi       Ascomycota                Dothideomycetes
#
#                                  Order                               Family  \
# 0  Aphelidiomycetes_ord_Incertae_sedis  Aphelidiomycetes_fam_Incertae_sedis
# 1                                 GS16              GS16_fam_Incertae_sedis
# 2        Ascomycota_ord_Incertae_sedis        Ascomycota_fam_Incertae_sedis
# 3                          Capnodiales                      Cladosporiaceae
# 4                          Capnodiales                      Cladosporiaceae
#
#                                  Genus  \
# 0  Aphelidiomycetes_gen_Incertae_sedis
# 1              GS16_gen_Incertae_sedis
# 2        Ascomycota_gen_Incertae_sedis
# 3                         Cladosporium
# 4                   Toxicocladosporium
#
#                                          genus_taxon  n  \
# 0  Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelid...  3
# 1  Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS...  5
# 2  Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis...  6
# 3  Fungi_Ascomycota_Dothideomycetes_Capnodiales_C...  4
# 4  Fungi_Ascomycota_Dothideomycetes_Capnodiales_C...  1
#
#                                 Genus_                                taxon
# 0  Aphelidiomycetes_gen_Incertae_sedis  Aphelidiomycetes_gen_Incertae_sedis
# 1              GS16_gen_Incertae_sedis              GS16_gen_Incertae_sedis
# 2        Ascomycota_gen_Incertae_sedis        Ascomycota_gen_Incertae_sedis
# 3                         Cladosporium                         Cladosporium
# 4                   Toxicocladosporium                   Toxicocladosporium

# %% [markdown]
# # Putting back genus name to ASV

# %%
mtax = pd.merge(dtax[['ASV','genus_taxon']],unique_genera,on='genus_taxon', how='left')
print(mtax.shape)
mtax = mtax[['ASV','taxon','Domain','Phylum','Class','Order','Family','Genus','genus_taxon']].reset_index(drop=True).set_index('ASV')
mtax.head()
# Out:
# (1130, 11)
#                                                      taxon Domain  \
# ASV
# 0432b9b1f641c119c2cfcb80d296ad60                  Wallemia  Fungi
# d245d0e6106daddd281a14becc2342ab  Fungi_gen_Incertae_sedis  Fungi
# 024cca61ca860ae60a3c4f992e383f53             Phialocephala  Fungi
# 5e68312f60a629b050527be14bf4c4ab                Alternaria  Fungi
# a06d6759b29ad98a8324cc7c82876632    unid_130_Chaetomiaceae  Fungi
#
#                                                     Phylum  \
# ASV
# 0432b9b1f641c119c2cfcb80d296ad60             Basidiomycota
# d245d0e6106daddd281a14becc2342ab  Fungi_phy_Incertae_sedis
# 024cca61ca860ae60a3c4f992e383f53                Ascomycota
# 5e68312f60a629b050527be14bf4c4ab                Ascomycota
# a06d6759b29ad98a8324cc7c82876632                Ascomycota
#
#                                                      Class  \
# ASV
# 0432b9b1f641c119c2cfcb80d296ad60           Wallemiomycetes
# d245d0e6106daddd281a14becc2342ab  Fungi_cls_Incertae_sedis
# 024cca61ca860ae60a3c4f992e383f53             Leotiomycetes
# 5e68312f60a629b050527be14bf4c4ab           Dothideomycetes
# a06d6759b29ad98a8324cc7c82876632           Sordariomycetes
#
#                                                      Order  \
# ASV
# 0432b9b1f641c119c2cfcb80d296ad60               Wallemiales
# d245d0e6106daddd281a14becc2342ab  Fungi_ord_Incertae_sedis
# 024cca61ca860ae60a3c4f992e383f53                Helotiales
# 5e68312f60a629b050527be14bf4c4ab              Pleosporales
# a06d6759b29ad98a8324cc7c82876632               Sordariales
#
#                                                     Family  \
# ASV
# 0432b9b1f641c119c2cfcb80d296ad60              Wallemiaceae
# d245d0e6106daddd281a14becc2342ab  Fungi_fam_Incertae_sedis
# 024cca61ca860ae60a3c4f992e383f53              Mollisiaceae
# 5e68312f60a629b050527be14bf4c4ab             Pleosporaceae
# a06d6759b29ad98a8324cc7c82876632             Chaetomiaceae
#
#                                                      Genus  \
# ASV
# 0432b9b1f641c119c2cfcb80d296ad60                  Wallemia
# d245d0e6106daddd281a14becc2342ab  Fungi_gen_Incertae_sedis
# 024cca61ca860ae60a3c4f992e383f53             Phialocephala
# 5e68312f60a629b050527be14bf4c4ab                Alternaria
# a06d6759b29ad98a8324cc7c82876632                      unid
#
#                                                                         genus_taxon
# ASV
# 0432b9b1f641c119c2cfcb80d296ad60  Fungi_Basidiomycota_Wallemiomycetes_Wallemiale...
# d245d0e6106daddd281a14becc2342ab  Fungi_Fungi_phy_Incertae_sedis_Fungi_cls_Incer...
# 024cca61ca860ae60a3c4f992e383f53  Fungi_Ascomycota_Leotiomycetes_Helotiales_Moll...
# 5e68312f60a629b050527be14bf4c4ab  Fungi_Ascomycota_Dothideomycetes_Pleosporales_...
# a06d6759b29ad98a8324cc7c82876632  Fungi_Ascomycota_Sordariomycetes_Sordariales_C...

# %% [markdown]
# # Collapsing ASV table by genera

# %%
df.head()
# Out:
#                                   ITS.Ctrl.neg.extraction.Racine  \
# 0432b9b1f641c119c2cfcb80d296ad60                               0
# d245d0e6106daddd281a14becc2342ab                               0
# 024cca61ca860ae60a3c4f992e383f53                               0
# 5e68312f60a629b050527be14bf4c4ab                               0
# a06d6759b29ad98a8324cc7c82876632                               0
#
#                                   ITS.Ctrl.neg.extraction.sol  ITS.Racine.AB1  \
# 0432b9b1f641c119c2cfcb80d296ad60                            0               0
# d245d0e6106daddd281a14becc2342ab                            0             184
# 024cca61ca860ae60a3c4f992e383f53                            0               0
# 5e68312f60a629b050527be14bf4c4ab                            0               0
# a06d6759b29ad98a8324cc7c82876632                            0               2
#
#                                   ITS.Racine.AB11  ITS.Racine.AB12  \
# 0432b9b1f641c119c2cfcb80d296ad60                0                0
# d245d0e6106daddd281a14becc2342ab                0               23
# 024cca61ca860ae60a3c4f992e383f53                0                0
# 5e68312f60a629b050527be14bf4c4ab                0              140
# a06d6759b29ad98a8324cc7c82876632                9                0
#
#                                   ITS.Racine.FORE.001  ITS.Racine.FORE.004  \
# 0432b9b1f641c119c2cfcb80d296ad60                    0                    0
# d245d0e6106daddd281a14becc2342ab                    0                    0
# 024cca61ca860ae60a3c4f992e383f53                    0                    0
# 5e68312f60a629b050527be14bf4c4ab                    0                    8
# a06d6759b29ad98a8324cc7c82876632                    0                    0
#
#                                   ITS.Racine.FORE.007  ITS.Racine.FP2.3.5  \
# 0432b9b1f641c119c2cfcb80d296ad60                    0                   0
# d245d0e6106daddd281a14becc2342ab                    0                   0
# 024cca61ca860ae60a3c4f992e383f53                    0                   0
# 5e68312f60a629b050527be14bf4c4ab                  767                  21
# a06d6759b29ad98a8324cc7c82876632                  101                   0
#
#                                   ITS.Racine.FP2.5.11  ...  ITS.sol.AB12  \
# 0432b9b1f641c119c2cfcb80d296ad60                    0  ...             0
# d245d0e6106daddd281a14becc2342ab                    0  ...             0
# 024cca61ca860ae60a3c4f992e383f53                    0  ...             0
# 5e68312f60a629b050527be14bf4c4ab                 8784  ...           155
# a06d6759b29ad98a8324cc7c82876632                    0  ...            39
#
#                                   ITS.sol.FORE.001  ITS.sol.FORE.004  \
# 0432b9b1f641c119c2cfcb80d296ad60                 0                 0
# d245d0e6106daddd281a14becc2342ab                 0                 0
# 024cca61ca860ae60a3c4f992e383f53                 0                 0
# 5e68312f60a629b050527be14bf4c4ab               154                54
# a06d6759b29ad98a8324cc7c82876632               132                 0
#
#                                   ITS.sol.FORE.007  ITS.sol.FP2.3.5  \
# 0432b9b1f641c119c2cfcb80d296ad60                 0                0
# d245d0e6106daddd281a14becc2342ab                 5                0
# 024cca61ca860ae60a3c4f992e383f53                 0                0
# 5e68312f60a629b050527be14bf4c4ab                55               14
# a06d6759b29ad98a8324cc7c82876632               161                5
#
#                                   ITS.sol.FP2.5.11  ITS.sol.FP2.5.17  \
# 0432b9b1f641c119c2cfcb80d296ad60                 0                 0
# d245d0e6106daddd281a14becc2342ab                19                 0
# 024cca61ca860ae60a3c4f992e383f53                 8                 0
# 5e68312f60a629b050527be14bf4c4ab                45                91
# a06d6759b29ad98a8324cc7c82876632              1085               228
#
#                                   ITS.sol.SP.4  ITS.sol.SP.45  ITS.sol.SP.56
# 0432b9b1f641c119c2cfcb80d296ad60             2              0              0
# d245d0e6106daddd281a14becc2342ab            25             69              0
# 024cca61ca860ae60a3c4f992e383f53             0              0              0
# 5e68312f60a629b050527be14bf4c4ab             0            225             33
# a06d6759b29ad98a8324cc7c82876632          3401            475             18
#
# [5 rows x 38 columns]

# %%
df_collapsed = df.groupby(mtax['genus_taxon']).sum()
df_collapsed.to_csv('ancombc_02_input_ITS_ASV.tsv', sep="\t", header=True, index=True)
df_collapsed.head()
# Out:
#                                                     ITS.Ctrl.neg.extraction.Racine  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                               0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                               0
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...                               0
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                               0
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                               0
#
#                                                     ITS.Ctrl.neg.extraction.sol  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                            0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                            0
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...                            0
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                            0
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                            0
#
#                                                     ITS.Racine.AB1  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...               0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...               0
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...               0
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...              12
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...               0
#
#                                                     ITS.Racine.AB11  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                0
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...               59
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...               45
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                0
#
#                                                     ITS.Racine.AB12  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                0
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...              655
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...               98
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                0
#
#                                                     ITS.Racine.FORE.001  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                    0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                   55
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...                    0
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                    0
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                    0
#
#                                                     ITS.Racine.FORE.004  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                    0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                    0
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...                   20
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                  163
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                    0
#
#                                                     ITS.Racine.FORE.007  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                    0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                    0
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...                    0
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                 4445
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                    0
#
#                                                     ITS.Racine.FP2.3.5  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                   0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                   0
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...                   0
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                 120
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                   0
#
#                                                     ITS.Racine.FP2.5.11  ...  \
# genus_taxon                                                              ...
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                    0  ...
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                    0  ...
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...                    0  ...
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                10098  ...
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                    0  ...
#
#                                                     ITS.sol.AB12  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...           131
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...            38
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...          1386
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...           218
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...             0
#
#                                                     ITS.sol.FORE.001  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                 0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...               366
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...               318
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...               189
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                 0
#
#                                                     ITS.sol.FORE.004  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                 0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                35
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...              1365
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...               308
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                 0
#
#                                                     ITS.sol.FORE.007  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                 0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...               596
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...               458
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...              2498
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                 0
#
#                                                     ITS.sol.FP2.3.5  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...               35
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...             1419
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...             1554
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                0
#
#                                                     ITS.sol.FP2.5.11  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                 0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                 0
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...              1861
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...               544
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                 0
#
#                                                     ITS.sol.FP2.5.17  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...                 0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                57
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...               456
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...               183
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                 0
#
#                                                     ITS.sol.SP.4  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...           444
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...          2435
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...          2179
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...            54
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...             0
#
#                                                     ITS.sol.SP.45  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...              0
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...           1006
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...            895
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...            182
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...              0
#
#                                                     ITS.sol.SP.56
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...            127
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...            620
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...            503
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...             49
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...              0
#
# [5 rows x 38 columns]

# %%
tax_collapsed = mtax.reset_index().drop(columns=['ASV']).drop_duplicates().reset_index(drop=True)
tax_collapsed = pd.merge(pd.DataFrame({"genus_taxon":df_collapsed.index.values}), tax_collapsed, on="genus_taxon", how = "left").set_index('genus_taxon')
print(tax_collapsed.shape)
tax_collapsed = tax_collapsed.drop(columns="Genus")
tax_collapsed['Genus'] = tax_collapsed.index.values
tax_collapsed.to_csv('ancombc_02_input_ITS_TAX.tsv', sep="\t", header=True, index=True)
tax_collapsed.head()
# Out:
# (226, 7)
#                                                                                   taxon  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...  Aphelidiomycetes_gen_Incertae_sedis
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...              GS16_gen_Incertae_sedis
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...        Ascomycota_gen_Incertae_sedis
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                         Cladosporium
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                   Toxicocladosporium
#
#                                                    Domain           Phylum  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...  Fungi  Aphelidiomycota
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...  Fungi  Aphelidiomycota
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...  Fungi       Ascomycota
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...  Fungi       Ascomycota
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...  Fungi       Ascomycota
#
#                                                                             Class  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...               Aphelidiomycetes
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...               Aphelidiomycetes
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...  Ascomycota_cls_Incertae_sedis
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                Dothideomycetes
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                Dothideomycetes
#
#                                                                                   Order  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...  Aphelidiomycetes_ord_Incertae_sedis
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...                                 GS16
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...        Ascomycota_ord_Incertae_sedis
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                          Capnodiales
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                          Capnodiales
#
#                                                                                  Family  \
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...  Aphelidiomycetes_fam_Incertae_sedis
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...              GS16_fam_Incertae_sedis
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...        Ascomycota_fam_Incertae_sedis
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                      Cladosporiaceae
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...                      Cladosporiaceae
#
#                                                                                                 Genus
# genus_taxon
# Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelidi...  Fungi_Aphelidiomycota_Aphelidiomycetes_Aphelid...
# Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS1...  Fungi_Aphelidiomycota_Aphelidiomycetes_GS16_GS...
# Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis_...  Fungi_Ascomycota_Ascomycota_cls_Incertae_sedis...
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...  Fungi_Ascomycota_Dothideomycetes_Capnodiales_C...
# Fungi_Ascomycota_Dothideomycetes_Capnodiales_Cl...  Fungi_Ascomycota_Dothideomycetes_Capnodiales_C...

# %%
mtax['taxon'].values
# Out:
# array(['Wallemia', 'Fungi_gen_Incertae_sedis', 'Phialocephala', ...,
#        'Thelephora', 'Candida', 'Chaetothyriales_gen_Incertae_sedis'],
#       dtype=object)
