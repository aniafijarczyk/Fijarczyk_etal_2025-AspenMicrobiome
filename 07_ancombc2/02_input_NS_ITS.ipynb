# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # ASV table

# %%
df = pd.read_csv("../01_data_prep/dataPrep_01_overview_ITS_ASV.tsv", sep="\t", header=0)
df.head()
# Out:
#                                   X001.ESSI.001.S.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         0
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                         0
#
#                                   X002.ESSI.001.S.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         18
# 5b86480031a596aff24cb779992a0369                          0
# dbdea2d4f96c7f353b406b225ea921d1                          0
# 2ab2a8d9866b45cbd9ee58d672b3056b                          0
# 8cdeb43b63256c27cafbe41d77f82b51                          0
#
#                                   X003.ESSI.001.S.Soil.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         0
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                         0
#
#                                   X005.ESSI.002.S.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                          0
# 5b86480031a596aff24cb779992a0369                          0
# dbdea2d4f96c7f353b406b225ea921d1                          0
# 2ab2a8d9866b45cbd9ee58d672b3056b                          0
# 8cdeb43b63256c27cafbe41d77f82b51                        201
#
#                                   X006.ESSI.002.S.Soil.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                        19
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                        63
#
#                                   X007.ESSI.003.S.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         0
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                         0
#
#                                   X008.ESSI.003.S.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                          0
# 5b86480031a596aff24cb779992a0369                          0
# dbdea2d4f96c7f353b406b225ea921d1                          0
# 2ab2a8d9866b45cbd9ee58d672b3056b                          0
# 8cdeb43b63256c27cafbe41d77f82b51                          0
#
#                                   X009.ESSI.003.S.Soil.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         0
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                         0
#
#                                   X010.ESSI.004.S.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         0
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                         0
#
#                                   X011.ESSI.004.S.Rhizo.ITS  ...  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                          0  ...
# 5b86480031a596aff24cb779992a0369                          0  ...
# dbdea2d4f96c7f353b406b225ea921d1                          0  ...
# 2ab2a8d9866b45cbd9ee58d672b3056b                          0  ...
# 8cdeb43b63256c27cafbe41d77f82b51                          0  ...
#
#                                   X128.Santiago.7.2.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                            0
# 5b86480031a596aff24cb779992a0369                            0
# dbdea2d4f96c7f353b406b225ea921d1                            0
# 2ab2a8d9866b45cbd9ee58d672b3056b                            0
# 8cdeb43b63256c27cafbe41d77f82b51                            0
#
#                                   X129.Santiago.7.3.Soil.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                           0
# 5b86480031a596aff24cb779992a0369                           0
# dbdea2d4f96c7f353b406b225ea921d1                           0
# 2ab2a8d9866b45cbd9ee58d672b3056b                           0
# 8cdeb43b63256c27cafbe41d77f82b51                           0
#
#                                   X130.Santiago.8.1.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                           0
# 5b86480031a596aff24cb779992a0369                           0
# dbdea2d4f96c7f353b406b225ea921d1                           0
# 2ab2a8d9866b45cbd9ee58d672b3056b                           0
# 8cdeb43b63256c27cafbe41d77f82b51                           0
#
#                                   X131.Santiago.8.2.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                            0
# 5b86480031a596aff24cb779992a0369                            0
# dbdea2d4f96c7f353b406b225ea921d1                            0
# 2ab2a8d9866b45cbd9ee58d672b3056b                            0
# 8cdeb43b63256c27cafbe41d77f82b51                            0
#
#                                   X133.Santiago.9.1.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                           0
# 5b86480031a596aff24cb779992a0369                           0
# dbdea2d4f96c7f353b406b225ea921d1                           0
# 2ab2a8d9866b45cbd9ee58d672b3056b                           0
# 8cdeb43b63256c27cafbe41d77f82b51                           0
#
#                                   X134.Santiago.9.2.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                            0
# 5b86480031a596aff24cb779992a0369                            0
# dbdea2d4f96c7f353b406b225ea921d1                            0
# 2ab2a8d9866b45cbd9ee58d672b3056b                            0
# 8cdeb43b63256c27cafbe41d77f82b51                            0
#
#                                   X135.Santiago.9.3.Soil.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                           0
# 5b86480031a596aff24cb779992a0369                           0
# dbdea2d4f96c7f353b406b225ea921d1                           0
# 2ab2a8d9866b45cbd9ee58d672b3056b                           0
# 8cdeb43b63256c27cafbe41d77f82b51                           0
#
#                                   X136.Santiago.10.1.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                            0
# 5b86480031a596aff24cb779992a0369                            0
# dbdea2d4f96c7f353b406b225ea921d1                            0
# 2ab2a8d9866b45cbd9ee58d672b3056b                            0
# 8cdeb43b63256c27cafbe41d77f82b51                            0
#
#                                   X137.Santiago.10.2.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                             0
# 5b86480031a596aff24cb779992a0369                             0
# dbdea2d4f96c7f353b406b225ea921d1                             0
# 2ab2a8d9866b45cbd9ee58d672b3056b                             0
# 8cdeb43b63256c27cafbe41d77f82b51                             0
#
#                                   X138.Santiago.10.3.Soil.ITS
# 3b3ca36e7e48dfeb9651339fb5e89db6                            0
# 5b86480031a596aff24cb779992a0369                           43
# dbdea2d4f96c7f353b406b225ea921d1                            0
# 2ab2a8d9866b45cbd9ee58d672b3056b                            0
# 8cdeb43b63256c27cafbe41d77f82b51                            0
#
# [5 rows x 133 columns]

# %%
dtax = pd.read_csv("../01_data_prep/dataPrep_01_overview_ITS_TAX.tsv", sep="\t", header=0)
dtax = dtax.fillna("unid")
dtax[dtax['Genus'].str.contains('unident')]
dtax[dtax['Genus'].str.contains('uncult')]
# Out:
# Empty DataFrame
# Columns: [Domain, Phylum, Class, Order, Family, Genus, Species]
# Index: []

# %%
dtax = pd.read_csv("../01_data_prep/dataPrep_01_overview_ITS_TAX.tsv", sep="\t", header=0)
print(dtax.shape)
dtax = dtax.fillna("unid")
#dtax = dtax.drop(columns=['Species'])
dtax['Domain'] = 'Fungi'
dtax['Phylum'] = dtax['Phylum'].str.replace('p__','')
dtax['Class'] = dtax['Class'].str.replace('c__','')
dtax['Order'] = dtax['Order'].str.replace('o__','')
dtax['Family'] = dtax['Family'].str.replace('f__','')
dtax['Genus'] = dtax['Genus'].str.replace('g__','')
dtax['Species'] = dtax['Species'].str.replace('s__','')
dtax = dtax.replace("unidentified","unid")
dtax = dtax.reset_index().rename(columns={'index':'ASV'})
dtax['genus_taxon'] = dtax.apply(lambda x: x['Domain']+'_'+x['Phylum']+'_'+x['Class']+'_'+x['Order']+'_'+x['Family']+'_'+x['Genus'], axis=1)
dtax.head()
# Out:
# (7320, 7)
#                                 ASV Domain      Phylum            Class  \
# 0  3b3ca36e7e48dfeb9651339fb5e89db6  Fungi        unid             unid
# 1  5b86480031a596aff24cb779992a0369  Fungi  Ascomycota  Dothideomycetes
# 2  dbdea2d4f96c7f353b406b225ea921d1  Fungi  Ascomycota   Eurotiomycetes
# 3  2ab2a8d9866b45cbd9ee58d672b3056b  Fungi  Ascomycota  Sordariomycetes
# 4  8cdeb43b63256c27cafbe41d77f82b51  Fungi  Ascomycota    Leotiomycetes
#
#             Order                          Family             Genus Species  \
# 0            unid                            unid              unid    unid
# 1     Capnodiales  Capnodiales_fam_Incertae_sedis  Pseudopenidiella    unid
# 2      Eurotiales                  Aspergillaceae              unid    unid
# 3  Myrmecridiales                            unid              unid    unid
# 4      Helotiales                 Hyaloscyphaceae              unid    unid
#
#                                          genus_taxon
# 0                     Fungi_unid_unid_unid_unid_unid
# 1  Fungi_Ascomycota_Dothideomycetes_Capnodiales_C...
# 2  Fungi_Ascomycota_Eurotiomycetes_Eurotiales_Asp...
# 3  Fungi_Ascomycota_Sordariomycetes_Myrmecridiale...
# 4  Fungi_Ascomycota_Leotiomycetes_Helotiales_Hyal...

# %% [markdown]
# # Groupby up to genus, add consecutive number & ungroup

# %%
unique_genera = dtax.groupby(['Domain','Phylum','Class','Order','Family','Genus','genus_taxon']).agg(n = ('ASV','count')).reset_index()
print(unique_genera.shape)
unique_genera.head()
# Out:
# (676, 8)
#   Domain      Phylum                Class                  Order  \
# 0  Fungi  Ascomycota  Archaeorhizomycetes  Archaeorhizomycetales
# 1  Fungi  Ascomycota  Archaeorhizomycetes                   unid
# 2  Fungi  Ascomycota      Dothideomycetes          Acrospermales
# 3  Fungi  Ascomycota      Dothideomycetes      Botryosphaeriales
# 4  Fungi  Ascomycota      Dothideomycetes      Botryosphaeriales
#
#                              Family              Genus  \
# 0            Archaeorhizomycetaceae  Archaeorhizomyces
# 1                              unid               unid
# 2  Acrospermales_fam_Incertae_sedis      Leptodiscella
# 3                Botryosphaeriaceae     Botryosphaeria
# 4                              unid               unid
#
#                                          genus_taxon   n
# 0  Fungi_Ascomycota_Archaeorhizomycetes_Archaeorh...  72
# 1  Fungi_Ascomycota_Archaeorhizomycetes_unid_unid...   3
# 2  Fungi_Ascomycota_Dothideomycetes_Acrospermales...   1
# 3  Fungi_Ascomycota_Dothideomycetes_Botryosphaeri...   1
# 4  Fungi_Ascomycota_Dothideomycetes_Botryosphaeri...   6

# %% [markdown]
# # Adding consecutive numbers to the unique genera

# %%
i=1
new_genus = []
for ind, row in unique_genera.iterrows():
    genus = row['Genus']
    if genus == 'unid':
        new_gen = 'unid'+'_'+str(i)
    else:
        new_gen = genus
    new_genus.append(new_gen)
    i+=1
new_genus
unique_genera['Genus_'] = new_genus
unique_genera.head()
# Out:
#   Domain      Phylum                Class                  Order  \
# 0  Fungi  Ascomycota  Archaeorhizomycetes  Archaeorhizomycetales
# 1  Fungi  Ascomycota  Archaeorhizomycetes                   unid
# 2  Fungi  Ascomycota      Dothideomycetes          Acrospermales
# 3  Fungi  Ascomycota      Dothideomycetes      Botryosphaeriales
# 4  Fungi  Ascomycota      Dothideomycetes      Botryosphaeriales
#
#                              Family              Genus  \
# 0            Archaeorhizomycetaceae  Archaeorhizomyces
# 1                              unid               unid
# 2  Acrospermales_fam_Incertae_sedis      Leptodiscella
# 3                Botryosphaeriaceae     Botryosphaeria
# 4                              unid               unid
#
#                                          genus_taxon   n             Genus_
# 0  Fungi_Ascomycota_Archaeorhizomycetes_Archaeorh...  72  Archaeorhizomyces
# 1  Fungi_Ascomycota_Archaeorhizomycetes_unid_unid...   3             unid_2
# 2  Fungi_Ascomycota_Dothideomycetes_Acrospermales...   1      Leptodiscella
# 3  Fungi_Ascomycota_Dothideomycetes_Botryosphaeri...   1     Botryosphaeria
# 4  Fungi_Ascomycota_Dothideomycetes_Botryosphaeri...   6             unid_5

# %% [markdown]
# # Naming unidentified

# %%
full_genus = []
for ind, row in unique_genera.iterrows():
    genus = row['Genus']
    if genus == 'unid':
        previous = [row['Domain'],row['Phylum'], row['Class'], row['Order'], row['Family']]
        previous_nonan = [ele for ele in previous if ele != 'unid']
        if previous_nonan:
            descriptor = previous_nonan[-1]
            full_gen = row['Genus_'] + "_" + descriptor
            #full_gen = row['Genus_']
        else:
            full_gen = row['Genus_']
    else:
        full_gen = row['Genus_']
    full_genus.append(full_gen)
unique_genera['taxon'] = full_genus
unique_genera.head()
# Out:
#   Domain      Phylum                Class                  Order  \
# 0  Fungi  Ascomycota  Archaeorhizomycetes  Archaeorhizomycetales
# 1  Fungi  Ascomycota  Archaeorhizomycetes                   unid
# 2  Fungi  Ascomycota      Dothideomycetes          Acrospermales
# 3  Fungi  Ascomycota      Dothideomycetes      Botryosphaeriales
# 4  Fungi  Ascomycota      Dothideomycetes      Botryosphaeriales
#
#                              Family              Genus  \
# 0            Archaeorhizomycetaceae  Archaeorhizomyces
# 1                              unid               unid
# 2  Acrospermales_fam_Incertae_sedis      Leptodiscella
# 3                Botryosphaeriaceae     Botryosphaeria
# 4                              unid               unid
#
#                                          genus_taxon   n             Genus_  \
# 0  Fungi_Ascomycota_Archaeorhizomycetes_Archaeorh...  72  Archaeorhizomyces
# 1  Fungi_Ascomycota_Archaeorhizomycetes_unid_unid...   3             unid_2
# 2  Fungi_Ascomycota_Dothideomycetes_Acrospermales...   1      Leptodiscella
# 3  Fungi_Ascomycota_Dothideomycetes_Botryosphaeri...   1     Botryosphaeria
# 4  Fungi_Ascomycota_Dothideomycetes_Botryosphaeri...   6             unid_5
#
#                         taxon
# 0           Archaeorhizomyces
# 1  unid_2_Archaeorhizomycetes
# 2               Leptodiscella
# 3              Botryosphaeria
# 4    unid_5_Botryosphaeriales

# %% [markdown]
# # Putting back genus name to ASV

# %%
mtax = pd.merge(dtax[['ASV','genus_taxon']],unique_genera,on='genus_taxon', how='left')
print(mtax.shape)
mtax = mtax[['ASV','taxon','Domain','Phylum','Class','Order','Family','Genus','genus_taxon']].reset_index(drop=True).set_index('ASV')
mtax.head()
# Out:
# (7320, 11)
#                                                      taxon Domain      Phylum  \
# ASV
# 3b3ca36e7e48dfeb9651339fb5e89db6            unid_676_Fungi  Fungi        unid
# 5b86480031a596aff24cb779992a0369          Pseudopenidiella  Fungi  Ascomycota
# dbdea2d4f96c7f353b406b225ea921d1   unid_116_Aspergillaceae  Fungi  Ascomycota
# 2ab2a8d9866b45cbd9ee58d672b3056b   unid_373_Myrmecridiales  Fungi  Ascomycota
# 8cdeb43b63256c27cafbe41d77f82b51  unid_221_Hyaloscyphaceae  Fungi  Ascomycota
#
#                                             Class           Order  \
# ASV
# 3b3ca36e7e48dfeb9651339fb5e89db6             unid            unid
# 5b86480031a596aff24cb779992a0369  Dothideomycetes     Capnodiales
# dbdea2d4f96c7f353b406b225ea921d1   Eurotiomycetes      Eurotiales
# 2ab2a8d9866b45cbd9ee58d672b3056b  Sordariomycetes  Myrmecridiales
# 8cdeb43b63256c27cafbe41d77f82b51    Leotiomycetes      Helotiales
#
#                                                           Family  \
# ASV
# 3b3ca36e7e48dfeb9651339fb5e89db6                            unid
# 5b86480031a596aff24cb779992a0369  Capnodiales_fam_Incertae_sedis
# dbdea2d4f96c7f353b406b225ea921d1                  Aspergillaceae
# 2ab2a8d9866b45cbd9ee58d672b3056b                            unid
# 8cdeb43b63256c27cafbe41d77f82b51                 Hyaloscyphaceae
#
#                                              Genus  \
# ASV
# 3b3ca36e7e48dfeb9651339fb5e89db6              unid
# 5b86480031a596aff24cb779992a0369  Pseudopenidiella
# dbdea2d4f96c7f353b406b225ea921d1              unid
# 2ab2a8d9866b45cbd9ee58d672b3056b              unid
# 8cdeb43b63256c27cafbe41d77f82b51              unid
#
#                                                                         genus_taxon
# ASV
# 3b3ca36e7e48dfeb9651339fb5e89db6                     Fungi_unid_unid_unid_unid_unid
# 5b86480031a596aff24cb779992a0369  Fungi_Ascomycota_Dothideomycetes_Capnodiales_C...
# dbdea2d4f96c7f353b406b225ea921d1  Fungi_Ascomycota_Eurotiomycetes_Eurotiales_Asp...
# 2ab2a8d9866b45cbd9ee58d672b3056b  Fungi_Ascomycota_Sordariomycetes_Myrmecridiale...
# 8cdeb43b63256c27cafbe41d77f82b51  Fungi_Ascomycota_Leotiomycetes_Helotiales_Hyal...

# %% [markdown]
# # Collapsing ASV table by genera

# %%
df.head()
# Out:
#                                   X001.ESSI.001.S.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         0
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                         0
#
#                                   X002.ESSI.001.S.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         18
# 5b86480031a596aff24cb779992a0369                          0
# dbdea2d4f96c7f353b406b225ea921d1                          0
# 2ab2a8d9866b45cbd9ee58d672b3056b                          0
# 8cdeb43b63256c27cafbe41d77f82b51                          0
#
#                                   X003.ESSI.001.S.Soil.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         0
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                         0
#
#                                   X005.ESSI.002.S.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                          0
# 5b86480031a596aff24cb779992a0369                          0
# dbdea2d4f96c7f353b406b225ea921d1                          0
# 2ab2a8d9866b45cbd9ee58d672b3056b                          0
# 8cdeb43b63256c27cafbe41d77f82b51                        201
#
#                                   X006.ESSI.002.S.Soil.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                        19
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                        63
#
#                                   X007.ESSI.003.S.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         0
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                         0
#
#                                   X008.ESSI.003.S.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                          0
# 5b86480031a596aff24cb779992a0369                          0
# dbdea2d4f96c7f353b406b225ea921d1                          0
# 2ab2a8d9866b45cbd9ee58d672b3056b                          0
# 8cdeb43b63256c27cafbe41d77f82b51                          0
#
#                                   X009.ESSI.003.S.Soil.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         0
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                         0
#
#                                   X010.ESSI.004.S.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                         0
# 5b86480031a596aff24cb779992a0369                         0
# dbdea2d4f96c7f353b406b225ea921d1                         0
# 2ab2a8d9866b45cbd9ee58d672b3056b                         0
# 8cdeb43b63256c27cafbe41d77f82b51                         0
#
#                                   X011.ESSI.004.S.Rhizo.ITS  ...  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                          0  ...
# 5b86480031a596aff24cb779992a0369                          0  ...
# dbdea2d4f96c7f353b406b225ea921d1                          0  ...
# 2ab2a8d9866b45cbd9ee58d672b3056b                          0  ...
# 8cdeb43b63256c27cafbe41d77f82b51                          0  ...
#
#                                   X128.Santiago.7.2.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                            0
# 5b86480031a596aff24cb779992a0369                            0
# dbdea2d4f96c7f353b406b225ea921d1                            0
# 2ab2a8d9866b45cbd9ee58d672b3056b                            0
# 8cdeb43b63256c27cafbe41d77f82b51                            0
#
#                                   X129.Santiago.7.3.Soil.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                           0
# 5b86480031a596aff24cb779992a0369                           0
# dbdea2d4f96c7f353b406b225ea921d1                           0
# 2ab2a8d9866b45cbd9ee58d672b3056b                           0
# 8cdeb43b63256c27cafbe41d77f82b51                           0
#
#                                   X130.Santiago.8.1.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                           0
# 5b86480031a596aff24cb779992a0369                           0
# dbdea2d4f96c7f353b406b225ea921d1                           0
# 2ab2a8d9866b45cbd9ee58d672b3056b                           0
# 8cdeb43b63256c27cafbe41d77f82b51                           0
#
#                                   X131.Santiago.8.2.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                            0
# 5b86480031a596aff24cb779992a0369                            0
# dbdea2d4f96c7f353b406b225ea921d1                            0
# 2ab2a8d9866b45cbd9ee58d672b3056b                            0
# 8cdeb43b63256c27cafbe41d77f82b51                            0
#
#                                   X133.Santiago.9.1.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                           0
# 5b86480031a596aff24cb779992a0369                           0
# dbdea2d4f96c7f353b406b225ea921d1                           0
# 2ab2a8d9866b45cbd9ee58d672b3056b                           0
# 8cdeb43b63256c27cafbe41d77f82b51                           0
#
#                                   X134.Santiago.9.2.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                            0
# 5b86480031a596aff24cb779992a0369                            0
# dbdea2d4f96c7f353b406b225ea921d1                            0
# 2ab2a8d9866b45cbd9ee58d672b3056b                            0
# 8cdeb43b63256c27cafbe41d77f82b51                            0
#
#                                   X135.Santiago.9.3.Soil.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                           0
# 5b86480031a596aff24cb779992a0369                           0
# dbdea2d4f96c7f353b406b225ea921d1                           0
# 2ab2a8d9866b45cbd9ee58d672b3056b                           0
# 8cdeb43b63256c27cafbe41d77f82b51                           0
#
#                                   X136.Santiago.10.1.Root.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                            0
# 5b86480031a596aff24cb779992a0369                            0
# dbdea2d4f96c7f353b406b225ea921d1                            0
# 2ab2a8d9866b45cbd9ee58d672b3056b                            0
# 8cdeb43b63256c27cafbe41d77f82b51                            0
#
#                                   X137.Santiago.10.2.Rhizo.ITS  \
# 3b3ca36e7e48dfeb9651339fb5e89db6                             0
# 5b86480031a596aff24cb779992a0369                             0
# dbdea2d4f96c7f353b406b225ea921d1                             0
# 2ab2a8d9866b45cbd9ee58d672b3056b                             0
# 8cdeb43b63256c27cafbe41d77f82b51                             0
#
#                                   X138.Santiago.10.3.Soil.ITS
# 3b3ca36e7e48dfeb9651339fb5e89db6                            0
# 5b86480031a596aff24cb779992a0369                           43
# dbdea2d4f96c7f353b406b225ea921d1                            0
# 2ab2a8d9866b45cbd9ee58d672b3056b                            0
# 8cdeb43b63256c27cafbe41d77f82b51                            0
#
# [5 rows x 133 columns]

# %%
df_collapsed = df.groupby(mtax['genus_taxon']).sum()
df_collapsed.to_csv('ancombc_02_input_ITS_ASV.tsv', sep="\t", header=True, index=True)
df_collapsed.head()
# Out:
#                                                     X001.ESSI.001.S.Root.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                        84
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                         0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
#
#                                                     X002.ESSI.001.S.Rhizo.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                        191
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                          0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                          0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                          0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                          0
#
#                                                     X003.ESSI.001.S.Soil.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                        92
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                         0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
#
#                                                     X005.ESSI.002.S.Rhizo.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                         88
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                          0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                          0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                          0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                          0
#
#                                                     X006.ESSI.002.S.Soil.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                       189
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                         9
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
#
#                                                     X007.ESSI.003.S.Root.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                         0
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                         0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
#
#                                                     X008.ESSI.003.S.Rhizo.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                         40
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                          0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                          0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                          0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                          0
#
#                                                     X009.ESSI.003.S.Soil.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                        30
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                         0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
#
#                                                     X010.ESSI.004.S.Root.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                         0
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                         0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                         0
#
#                                                     X011.ESSI.004.S.Rhizo.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                         12
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                         13
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                          0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                          0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                          0
#
#                                                     ...  \
# genus_taxon                                         ...
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...  ...
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...  ...
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...  ...
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...  ...
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...  ...
#
#                                                     X128.Santiago.7.2.Rhizo.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                           24
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                            0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                            0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                            0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                            0
#
#                                                     X129.Santiago.7.3.Soil.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                          51
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                           0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                           0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                           0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                           8
#
#                                                     X130.Santiago.8.1.Root.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                          35
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                           0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                           0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                           0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                           0
#
#                                                     X131.Santiago.8.2.Rhizo.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                            9
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                            0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                            0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                            0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                            0
#
#                                                     X133.Santiago.9.1.Root.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                           8
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                           0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                           0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                           0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                           0
#
#                                                     X134.Santiago.9.2.Rhizo.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                           10
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                            0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                            0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                            0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                            0
#
#                                                     X135.Santiago.9.3.Soil.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                          20
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                           0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                           0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                           0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                           0
#
#                                                     X136.Santiago.10.1.Root.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                           20
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                            0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                            0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                            0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                            0
#
#                                                     X137.Santiago.10.2.Rhizo.ITS  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                            37
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                             0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                             0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                             5
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                             0
#
#                                                     X138.Santiago.10.3.Soil.ITS
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...                          146
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                            0
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...                            0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                            0
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                            0
#
# [5 rows x 133 columns]

# %%
tax_collapsed = mtax.reset_index().drop(columns=['ASV']).drop_duplicates().reset_index(drop=True)
tax_collapsed = pd.merge(pd.DataFrame({"genus_taxon":df_collapsed.index.values}), tax_collapsed, on="genus_taxon", how = "left").set_index('genus_taxon')
print(tax_collapsed.shape)
tax_collapsed = tax_collapsed.drop(columns="Genus")
tax_collapsed['Genus'] = tax_collapsed.index.values
tax_collapsed.to_csv('ancombc_02_input_ITS_TAX.tsv', sep="\t", header=True, index=True)
tax_collapsed.head()
# Out:
# (676, 7)
#                                                                          taxon  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...           Archaeorhizomyces
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...  unid_2_Archaeorhizomycetes
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...               Leptodiscella
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...              Botryosphaeria
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...    unid_5_Botryosphaeriales
#
#                                                    Domain      Phylum  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...  Fungi  Ascomycota
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...  Fungi  Ascomycota
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...  Fungi  Ascomycota
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...  Fungi  Ascomycota
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...  Fungi  Ascomycota
#
#                                                                   Class  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...  Archaeorhizomycetes
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...  Archaeorhizomycetes
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...      Dothideomycetes
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...      Dothideomycetes
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...      Dothideomycetes
#
#                                                                     Order  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...  Archaeorhizomycetales
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                   unid
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...          Acrospermales
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...      Botryosphaeriales
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...      Botryosphaeriales
#
#                                                                               Family  \
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...            Archaeorhizomycetaceae
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...                              unid
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...  Acrospermales_fam_Incertae_sedis
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                Botryosphaeriaceae
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...                              unid
#
#                                                                                                 Genus
# genus_taxon
# Fungi_Ascomycota_Archaeorhizomycetes_Archaeorhi...  Fungi_Ascomycota_Archaeorhizomycetes_Archaeorh...
# Fungi_Ascomycota_Archaeorhizomycetes_unid_unid_...  Fungi_Ascomycota_Archaeorhizomycetes_unid_unid...
# Fungi_Ascomycota_Dothideomycetes_Acrospermales_...  Fungi_Ascomycota_Dothideomycetes_Acrospermales...
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...  Fungi_Ascomycota_Dothideomycetes_Botryosphaeri...
# Fungi_Ascomycota_Dothideomycetes_Botryosphaeria...  Fungi_Ascomycota_Dothideomycetes_Botryosphaeri...

# %%
mtax['taxon'].values
# Out:
# array(['unid_676_Fungi', 'Pseudopenidiella', 'unid_116_Aspergillaceae',
#        ..., 'Lophium', 'Xerocomus', 'unid_622_Basidiomycota'],
#       dtype=object)
